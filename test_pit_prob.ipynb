# %%
import pomegranate
import numpy
numpy.random.seed(42)

# %%
pit_1_2_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_1_3_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_1_4_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_2_1_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_2_2_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_2_3_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_2_4_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_3_1_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_3_2_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_3_3_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_3_4_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_4_1_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_4_2_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_4_3_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})
pit_4_4_prob = pomegranate.distributions.DiscreteDistribution({'True': 0.2, 'False': 0.8})

# %%
# 1_1
breeze_1_1_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True',   1.0 ],
         [ 'True', 'True',  'False',  0.0 ],
         [ 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'False',  0.0 ],
         [ 'False', 'False', 'True',  0.0 ],
         [ 'False', 'False', 'False', 1.0 ]], [pit_1_2_prob, pit_2_1_prob])

# 1_2
breeze_1_2_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True',  'True',  1.0 ],
         [ 'False', 'False','True',  'False', 0.0 ],
         
         [ 'True', 'True',  'False', 'True',   1.0 ],
         [ 'True', 'True',  'False', 'False',  0.0 ],
         [ 'True', 'False', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','False',  'True',  0.0 ],
         [ 'False', 'False','False',  'False', 1.0 ],], [pit_1_2_prob, pit_1_3_prob, pit_2_2_prob])

# 1_3
breeze_1_3_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','False','True',   'True',  1.0 ],
         [ 'False', 'False','False','True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','False','False',   'True',  0.0 ],
         [ 'False', 'False','False','False',   'False', 1.0 ],], [pit_1_2_prob, pit_1_3_prob, pit_1_4_prob, pit_2_3_prob])


# 1_4
breeze_1_4_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True',  'True',  1.0 ],
         [ 'False', 'False','True',  'False', 0.0 ],
         
         [ 'True', 'True',  'False', 'True',   1.0 ],
         [ 'True', 'True',  'False', 'False',  0.0 ],
         [ 'True', 'False', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','False',  'True',  0.0 ],
         [ 'False', 'False','False',  'False', 1.0 ],], [pit_1_3_prob, pit_1_4_prob, pit_2_4_prob])

# %%
# 2_1
breeze_2_1_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True',  'True',  1.0 ],
         [ 'False', 'False','True',  'False', 0.0 ],
         
         [ 'True', 'True',  'False', 'True',   1.0 ],
         [ 'True', 'True',  'False', 'False',  0.0 ],
         [ 'True', 'False', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','False',  'True',  0.0 ],
         [ 'False', 'False','False',  'False', 1.0 ],], [pit_2_1_prob, pit_2_2_prob, pit_3_1_prob])

# 2_2
breeze_2_2_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True', 'True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True', 'True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True', 'True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True', 'True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True', 'True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True', 'True',  'False',  0.0 ],
         [ 'False', 'False','False','True', 'True',   'True',  1.0 ],
         [ 'False', 'False','False','True', 'True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'True', 'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','True', 'False','True',   'True',  1.0 ],
         [ 'False', 'False','True', 'False','True',   'False', 0.0 ],
         [ 'True', 'True',  'False','False','True',   'True',   1.0 ],
         [ 'True', 'True',  'False','False','True',   'False',  0.0 ],
         [ 'True', 'False', 'False','False','True',   'True',   1.0 ],
         [ 'True', 'False', 'False','False','True',   'False',  0.0 ],
         [ 'False', 'True', 'False','False','True',   'True',   1.0 ],
         [ 'False', 'True', 'False','False','True',   'False',  0.0 ],
         [ 'False', 'False','False','False','True',    'True',  1.0 ],
         [ 'False', 'False','False','False','True',    'False', 0.0 ],

         [ 'True', 'True',  'True', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','True', 'False',  'True',   1.0 ],
         [ 'True', 'True',  'False','True', 'False',  'False',  0.0 ],
         [ 'True', 'False', 'False','True', 'False',  'True',   1.0 ],
         [ 'True', 'False', 'False','True', 'False',  'False',  0.0 ],
         [ 'False', 'True', 'False','True', 'False',  'True',   1.0 ],
         [ 'False', 'True', 'False','True', 'False',  'False',  0.0 ],
         [ 'False', 'False','False','True', 'False',   'True',  1.0 ],
         [ 'False', 'False','False','True', 'False',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'True', 'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','True', 'False','False',   'True',  1.0 ],
         [ 'False', 'False','True', 'False','False',   'False', 0.0 ],
         [ 'True', 'True',  'False','False','False',   'True',   1.0 ],
         [ 'True', 'True',  'False','False','False',   'False',  0.0 ],
         [ 'True', 'False', 'False','False','False',   'True',   1.0 ],
         [ 'True', 'False', 'False','False','False',   'False',  0.0 ],
         [ 'False', 'True', 'False','False','False',   'True',   1.0 ],
         [ 'False', 'True', 'False','False','False',   'False',  0.0 ],
         [ 'False', 'False','False','False','False',    'True',  0.0 ],
         [ 'False', 'False','False','False','False',    'False', 1.0 ],], [pit_2_1_prob, pit_2_2_prob, pit_2_3_prob, pit_1_2_prob, pit_3_2_prob])

# 2_3
breeze_2_3_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True', 'True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True', 'True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True', 'True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True', 'True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True', 'True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True', 'True',  'False',  0.0 ],
         [ 'False', 'False','False','True', 'True',   'True',  1.0 ],
         [ 'False', 'False','False','True', 'True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'True', 'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','True', 'False','True',   'True',  1.0 ],
         [ 'False', 'False','True', 'False','True',   'False', 0.0 ],
         [ 'True', 'True',  'False','False','True',   'True',   1.0 ],
         [ 'True', 'True',  'False','False','True',   'False',  0.0 ],
         [ 'True', 'False', 'False','False','True',   'True',   1.0 ],
         [ 'True', 'False', 'False','False','True',   'False',  0.0 ],
         [ 'False', 'True', 'False','False','True',   'True',   1.0 ],
         [ 'False', 'True', 'False','False','True',   'False',  0.0 ],
         [ 'False', 'False','False','False','True',    'True',  1.0 ],
         [ 'False', 'False','False','False','True',    'False', 0.0 ],

         [ 'True', 'True',  'True', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','True', 'False',  'True',   1.0 ],
         [ 'True', 'True',  'False','True', 'False',  'False',  0.0 ],
         [ 'True', 'False', 'False','True', 'False',  'True',   1.0 ],
         [ 'True', 'False', 'False','True', 'False',  'False',  0.0 ],
         [ 'False', 'True', 'False','True', 'False',  'True',   1.0 ],
         [ 'False', 'True', 'False','True', 'False',  'False',  0.0 ],
         [ 'False', 'False','False','True', 'False',   'True',  1.0 ],
         [ 'False', 'False','False','True', 'False',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'True', 'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','True', 'False','False',   'True',  1.0 ],
         [ 'False', 'False','True', 'False','False',   'False', 0.0 ],
         [ 'True', 'True',  'False','False','False',   'True',   1.0 ],
         [ 'True', 'True',  'False','False','False',   'False',  0.0 ],
         [ 'True', 'False', 'False','False','False',   'True',   1.0 ],
         [ 'True', 'False', 'False','False','False',   'False',  0.0 ],
         [ 'False', 'True', 'False','False','False',   'True',   1.0 ],
         [ 'False', 'True', 'False','False','False',   'False',  0.0 ],
         [ 'False', 'False','False','False','False',    'True',  0.0 ],
         [ 'False', 'False','False','False','False',    'False', 1.0 ],], [pit_2_2_prob, pit_2_3_prob, pit_2_4_prob, pit_1_3_prob, pit_3_3_prob])

# 2_4
breeze_2_4_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','False','True',   'True',  1.0 ],
         [ 'False', 'False','False','True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','False','False',   'True',  0.0 ],
         [ 'False', 'False','False','False',   'False', 1.0 ],], [pit_2_3_prob, pit_2_4_prob, pit_1_4_prob, pit_3_4_prob])

# %%
# 3_1
breeze_3_1_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','False','True',   'True',  1.0 ],
         [ 'False', 'False','False','True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','False','False',   'True',  0.0 ],
         [ 'False', 'False','False','False',   'False', 1.0 ],], [pit_3_1_prob, pit_3_2_prob, pit_2_1_prob, pit_4_1_prob])

# 3_2
breeze_3_2_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True', 'True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True', 'True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True', 'True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True', 'True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True', 'True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True', 'True',  'False',  0.0 ],
         [ 'False', 'False','False','True', 'True',   'True',  1.0 ],
         [ 'False', 'False','False','True', 'True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'True', 'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','True', 'False','True',   'True',  1.0 ],
         [ 'False', 'False','True', 'False','True',   'False', 0.0 ],
         [ 'True', 'True',  'False','False','True',   'True',   1.0 ],
         [ 'True', 'True',  'False','False','True',   'False',  0.0 ],
         [ 'True', 'False', 'False','False','True',   'True',   1.0 ],
         [ 'True', 'False', 'False','False','True',   'False',  0.0 ],
         [ 'False', 'True', 'False','False','True',   'True',   1.0 ],
         [ 'False', 'True', 'False','False','True',   'False',  0.0 ],
         [ 'False', 'False','False','False','True',    'True',  1.0 ],
         [ 'False', 'False','False','False','True',    'False', 0.0 ],

         [ 'True', 'True',  'True', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','True', 'False',  'True',   1.0 ],
         [ 'True', 'True',  'False','True', 'False',  'False',  0.0 ],
         [ 'True', 'False', 'False','True', 'False',  'True',   1.0 ],
         [ 'True', 'False', 'False','True', 'False',  'False',  0.0 ],
         [ 'False', 'True', 'False','True', 'False',  'True',   1.0 ],
         [ 'False', 'True', 'False','True', 'False',  'False',  0.0 ],
         [ 'False', 'False','False','True', 'False',   'True',  1.0 ],
         [ 'False', 'False','False','True', 'False',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'True', 'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','True', 'False','False',   'True',  1.0 ],
         [ 'False', 'False','True', 'False','False',   'False', 0.0 ],
         [ 'True', 'True',  'False','False','False',   'True',   1.0 ],
         [ 'True', 'True',  'False','False','False',   'False',  0.0 ],
         [ 'True', 'False', 'False','False','False',   'True',   1.0 ],
         [ 'True', 'False', 'False','False','False',   'False',  0.0 ],
         [ 'False', 'True', 'False','False','False',   'True',   1.0 ],
         [ 'False', 'True', 'False','False','False',   'False',  0.0 ],
         [ 'False', 'False','False','False','False',    'True',  0.0 ],
         [ 'False', 'False','False','False','False',    'False', 1.0 ],], [pit_3_1_prob, pit_3_2_prob, pit_3_3_prob, pit_2_2_prob, pit_4_2_prob])

# 3_3
breeze_3_3_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True', 'True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True', 'True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True', 'True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True', 'True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True', 'True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True', 'True',  'False',  0.0 ],
         [ 'False', 'False','False','True', 'True',   'True',  1.0 ],
         [ 'False', 'False','False','True', 'True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'True', 'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','True', 'False','True',   'True',  1.0 ],
         [ 'False', 'False','True', 'False','True',   'False', 0.0 ],
         [ 'True', 'True',  'False','False','True',   'True',   1.0 ],
         [ 'True', 'True',  'False','False','True',   'False',  0.0 ],
         [ 'True', 'False', 'False','False','True',   'True',   1.0 ],
         [ 'True', 'False', 'False','False','True',   'False',  0.0 ],
         [ 'False', 'True', 'False','False','True',   'True',   1.0 ],
         [ 'False', 'True', 'False','False','True',   'False',  0.0 ],
         [ 'False', 'False','False','False','True',    'True',  1.0 ],
         [ 'False', 'False','False','False','True',    'False', 0.0 ],

         [ 'True', 'True',  'True', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','True', 'False',  'True',   1.0 ],
         [ 'True', 'True',  'False','True', 'False',  'False',  0.0 ],
         [ 'True', 'False', 'False','True', 'False',  'True',   1.0 ],
         [ 'True', 'False', 'False','True', 'False',  'False',  0.0 ],
         [ 'False', 'True', 'False','True', 'False',  'True',   1.0 ],
         [ 'False', 'True', 'False','True', 'False',  'False',  0.0 ],
         [ 'False', 'False','False','True', 'False',   'True',  1.0 ],
         [ 'False', 'False','False','True', 'False',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'True', 'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','True', 'False','False',   'True',  1.0 ],
         [ 'False', 'False','True', 'False','False',   'False', 0.0 ],
         [ 'True', 'True',  'False','False','False',   'True',   1.0 ],
         [ 'True', 'True',  'False','False','False',   'False',  0.0 ],
         [ 'True', 'False', 'False','False','False',   'True',   1.0 ],
         [ 'True', 'False', 'False','False','False',   'False',  0.0 ],
         [ 'False', 'True', 'False','False','False',   'True',   1.0 ],
         [ 'False', 'True', 'False','False','False',   'False',  0.0 ],
         [ 'False', 'False','False','False','False',    'True',  0.0 ],
         [ 'False', 'False','False','False','False',    'False', 1.0 ],], [pit_3_2_prob, pit_3_3_prob, pit_3_4_prob, pit_2_3_prob, pit_4_3_prob])

# 3_4
breeze_3_4_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','False','True',   'True',  1.0 ],
         [ 'False', 'False','False','True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','False','False',   'True',  0.0 ],
         [ 'False', 'False','False','False',   'False', 1.0 ],], [pit_3_3_prob, pit_3_4_prob, pit_2_4_prob, pit_4_4_prob])

# %%
# 4_1
breeze_4_1_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True',  'True',  1.0 ],
         [ 'False', 'False','True',  'False', 0.0 ],
         
         [ 'True', 'True',  'False', 'True',   1.0 ],
         [ 'True', 'True',  'False', 'False',  0.0 ],
         [ 'True', 'False', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','False',  'True',  0.0 ],
         [ 'False', 'False','False',  'False', 1.0 ],], [pit_4_1_prob, pit_4_2_prob, pit_3_1_prob])

# 4_2
breeze_4_2_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','False','True',   'True',  1.0 ],
         [ 'False', 'False','False','True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','False','False',   'True',  0.0 ],
         [ 'False', 'False','False','False',   'False', 1.0 ],], [pit_4_1_prob, pit_4_2_prob, pit_4_3_prob, pit_3_2_prob])

# 4_3
breeze_4_3_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True', 'True',  'True',  1.0 ],
         [ 'False', 'False','True', 'True',  'False', 0.0 ],
         [ 'True', 'True',  'False','True',  'True',   1.0 ],
         [ 'True', 'True',  'False','True',  'False',  0.0 ],
         [ 'True', 'False', 'False','True',  'True',   1.0 ],
         [ 'True', 'False', 'False','True',  'False',  0.0 ],
         [ 'False', 'True', 'False','True',  'True',   1.0 ],
         [ 'False', 'True', 'False','True',  'False',  0.0 ],
         [ 'False', 'False','False','True',   'True',  1.0 ],
         [ 'False', 'False','False','True',   'False', 0.0 ],

         [ 'True', 'True',  'True', 'False', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','True', 'False',  'True',  1.0 ],
         [ 'False', 'False','True', 'False',  'False', 0.0 ],
         [ 'True', 'True',  'False','False',  'True',   1.0 ],
         [ 'True', 'True',  'False','False',  'False',  0.0 ],
         [ 'True', 'False', 'False','False',  'True',   1.0 ],
         [ 'True', 'False', 'False','False',  'False',  0.0 ],
         [ 'False', 'True', 'False','False',  'True',   1.0 ],
         [ 'False', 'True', 'False','False',  'False',  0.0 ],
         [ 'False', 'False','False','False',   'True',  0.0 ],
         [ 'False', 'False','False','False',   'False', 1.0 ],], [pit_4_2_prob, pit_4_3_prob, pit_4_4_prob, pit_3_3_prob])

# 4_4
breeze_4_4_prob = pomegranate.distributions.ConditionalProbabilityTable(
        [[ 'True', 'True',  'True', 'True',   1.0 ],
         [ 'True', 'True',  'True', 'False',  0.0 ],
         [ 'True', 'False', 'True', 'True',   1.0 ],
         [ 'True', 'False', 'True', 'False',  0.0 ],
         [ 'False', 'True', 'True', 'True',   1.0 ],
         [ 'False', 'True', 'True', 'False',  0.0 ],
         [ 'False', 'False','True',  'True',  1.0 ],
         [ 'False', 'False','True',  'False', 0.0 ],
         
         [ 'True', 'True',  'False', 'True',   1.0 ],
         [ 'True', 'True',  'False', 'False',  0.0 ],
         [ 'True', 'False', 'False', 'True',   1.0 ],
         [ 'True', 'False', 'False', 'False',  0.0 ],
         [ 'False', 'True', 'False', 'True',   1.0 ],
         [ 'False', 'True', 'False', 'False',  0.0 ],
         [ 'False', 'False','False',  'True',  0.0 ],
         [ 'False', 'False','False',  'False', 1.0 ],], [pit_4_3_prob, pit_4_4_prob, pit_3_4_prob])

# %%
# State objects hold both the distribution, and a high level name.
pit_1_2_prob_state = pomegranate.State(pit_1_2_prob, name="pit_1_2_prob")
pit_1_3_prob_state = pomegranate.State(pit_1_3_prob, name="pit_1_3_prob")
pit_1_4_prob_state = pomegranate.State(pit_1_4_prob, name="pit_1_4_prob")

pit_2_1_prob_state = pomegranate.State(pit_2_1_prob, name="pit_2_1_prob")
pit_2_2_prob_state = pomegranate.State(pit_2_2_prob, name="pit_2_2_prob")
pit_2_3_prob_state = pomegranate.State(pit_2_3_prob, name="pit_2_3_prob")
pit_2_4_prob_state = pomegranate.State(pit_2_4_prob, name="pit_2_4_prob")

pit_3_1_prob_state = pomegranate.State(pit_3_1_prob, name="pit_3_1_prob")
pit_3_2_prob_state = pomegranate.State(pit_3_2_prob, name="pit_3_2_prob")
pit_3_3_prob_state = pomegranate.State(pit_3_3_prob, name="pit_3_3_prob")
pit_3_4_prob_state = pomegranate.State(pit_3_4_prob, name="pit_3_4_prob")

pit_4_1_prob_state = pomegranate.State(pit_4_1_prob, name="pit_4_1_prob")
pit_4_2_prob_state = pomegranate.State(pit_4_2_prob, name="pit_4_2_prob")
pit_4_3_prob_state = pomegranate.State(pit_4_3_prob, name="pit_4_3_prob")
pit_4_4_prob_state = pomegranate.State(pit_4_4_prob, name="pit_4_4_prob")

breeze_1_1_prob_state = pomegranate.State(breeze_1_1_prob, name="breeze_1_1_prob")
breeze_1_2_prob_state = pomegranate.State(breeze_1_2_prob, name="breeze_1_2_prob")
breeze_1_3_prob_state = pomegranate.State(breeze_1_3_prob, name="breeze_1_3_prob")
breeze_1_4_prob_state = pomegranate.State(breeze_1_4_prob, name="breeze_1_4_prob")

breeze_2_1_prob_state = pomegranate.State(breeze_2_1_prob, name="breeze_2_1_prob")
breeze_2_2_prob_state = pomegranate.State(breeze_2_2_prob, name="breeze_2_2_prob")
breeze_2_3_prob_state = pomegranate.State(breeze_2_3_prob, name="breeze_2_3_prob")
breeze_2_4_prob_state = pomegranate.State(breeze_2_4_prob, name="breeze_2_4_prob")

breeze_3_1_prob_state = pomegranate.State(breeze_3_1_prob, name="breeze_3_1_prob")
breeze_3_2_prob_state = pomegranate.State(breeze_3_2_prob, name="breeze_3_2_prob")
breeze_3_3_prob_state = pomegranate.State(breeze_3_3_prob, name="breeze_3_3_prob")
breeze_3_4_prob_state = pomegranate.State(breeze_3_4_prob, name="breeze_3_4_prob")

breeze_4_1_prob_state = pomegranate.State(breeze_4_1_prob, name="breeze_4_1_prob")
breeze_4_2_prob_state = pomegranate.State(breeze_4_2_prob, name="breeze_4_2_prob")
breeze_4_3_prob_state = pomegranate.State(breeze_4_3_prob, name="breeze_4_3_prob")
breeze_4_4_prob_state = pomegranate.State(breeze_4_4_prob, name="breeze_4_4_prob")

# %%
# Create the Bayesian network object with a useful name
pit_model = pomegranate.BayesianNetwork("Pit Location")
pit_model.add_states(pit_1_2_prob_state, pit_1_3_prob_state, pit_1_4_prob_state,
pit_2_1_prob_state, pit_2_2_prob_state, pit_2_3_prob_state, pit_2_4_prob_state,
pit_3_1_prob_state, pit_3_2_prob_state, pit_3_3_prob_state, pit_3_4_prob_state,
pit_4_1_prob_state, pit_4_2_prob_state, pit_4_3_prob_state, pit_4_4_prob_state,
breeze_1_1_prob_state, breeze_2_1_prob_state, breeze_3_1_prob_state, breeze_4_1_prob_state,
breeze_1_2_prob_state, breeze_2_2_prob_state, breeze_3_2_prob_state, breeze_4_2_prob_state,
breeze_1_3_prob_state, breeze_2_3_prob_state, breeze_3_3_prob_state, breeze_4_3_prob_state,
breeze_1_4_prob_state, breeze_2_4_prob_state, breeze_3_4_prob_state, breeze_4_4_prob_state)

# %%
pit_model.add_edge(pit_1_2_prob_state, breeze_1_2_prob_state)
pit_model.add_edge(pit_1_2_prob_state, breeze_2_2_prob_state)
pit_model.add_edge(pit_1_2_prob_state, breeze_1_3_prob_state)

pit_model.add_edge(pit_1_3_prob_state, breeze_1_2_prob_state)
pit_model.add_edge(pit_1_3_prob_state, breeze_1_3_prob_state)
pit_model.add_edge(pit_1_3_prob_state, breeze_1_4_prob_state)
pit_model.add_edge(pit_1_3_prob_state, breeze_2_3_prob_state)

pit_model.add_edge(pit_1_4_prob_state, breeze_1_3_prob_state)
pit_model.add_edge(pit_1_4_prob_state, breeze_1_4_prob_state)
pit_model.add_edge(pit_1_4_prob_state, breeze_2_4_prob_state)

pit_model.add_edge(pit_2_1_prob_state, breeze_2_1_prob_state)
pit_model.add_edge(pit_2_1_prob_state, breeze_2_2_prob_state)
pit_model.add_edge(pit_2_1_prob_state, breeze_1_1_prob_state)
pit_model.add_edge(pit_2_1_prob_state, breeze_3_1_prob_state)

pit_model.add_edge(pit_2_2_prob_state, breeze_2_1_prob_state)
pit_model.add_edge(pit_2_2_prob_state, breeze_2_2_prob_state)
pit_model.add_edge(pit_2_2_prob_state, breeze_2_3_prob_state)
pit_model.add_edge(pit_2_2_prob_state, breeze_1_2_prob_state)
pit_model.add_edge(pit_2_2_prob_state, breeze_3_2_prob_state)

pit_model.add_edge(pit_2_3_prob_state, breeze_2_2_prob_state)
pit_model.add_edge(pit_2_3_prob_state, breeze_2_3_prob_state)
pit_model.add_edge(pit_2_3_prob_state, breeze_2_4_prob_state)
pit_model.add_edge(pit_2_3_prob_state, breeze_1_3_prob_state)
pit_model.add_edge(pit_2_3_prob_state, breeze_3_3_prob_state)

pit_model.add_edge(pit_2_4_prob_state, breeze_2_3_prob_state)
pit_model.add_edge(pit_2_4_prob_state, breeze_2_4_prob_state)
pit_model.add_edge(pit_2_4_prob_state, breeze_1_4_prob_state)
pit_model.add_edge(pit_2_4_prob_state, breeze_3_4_prob_state)

pit_model.add_edge(pit_3_1_prob_state, breeze_3_1_prob_state)
pit_model.add_edge(pit_3_1_prob_state, breeze_3_2_prob_state)
pit_model.add_edge(pit_3_1_prob_state, breeze_2_1_prob_state)
pit_model.add_edge(pit_3_1_prob_state, breeze_4_1_prob_state)

pit_model.add_edge(pit_3_2_prob_state, breeze_3_1_prob_state)
pit_model.add_edge(pit_3_2_prob_state, breeze_3_2_prob_state)
pit_model.add_edge(pit_3_2_prob_state, breeze_3_3_prob_state)
pit_model.add_edge(pit_3_2_prob_state, breeze_2_2_prob_state)
pit_model.add_edge(pit_3_2_prob_state, breeze_4_2_prob_state)

pit_model.add_edge(pit_3_3_prob_state, breeze_3_2_prob_state)
pit_model.add_edge(pit_3_3_prob_state, breeze_3_3_prob_state)
pit_model.add_edge(pit_3_3_prob_state, breeze_3_4_prob_state)
pit_model.add_edge(pit_3_3_prob_state, breeze_2_3_prob_state)
pit_model.add_edge(pit_3_3_prob_state, breeze_4_3_prob_state)

pit_model.add_edge(pit_3_4_prob_state, breeze_3_3_prob_state)
pit_model.add_edge(pit_3_4_prob_state, breeze_3_4_prob_state)
pit_model.add_edge(pit_3_4_prob_state, breeze_2_4_prob_state)
pit_model.add_edge(pit_3_4_prob_state, breeze_4_4_prob_state)

pit_model.add_edge(pit_4_1_prob_state, breeze_4_1_prob_state)
pit_model.add_edge(pit_4_1_prob_state, breeze_4_2_prob_state)
pit_model.add_edge(pit_4_1_prob_state, breeze_3_1_prob_state)

pit_model.add_edge(pit_4_2_prob_state, breeze_4_1_prob_state)
pit_model.add_edge(pit_4_2_prob_state, breeze_4_2_prob_state)
pit_model.add_edge(pit_4_2_prob_state, breeze_4_3_prob_state)
pit_model.add_edge(pit_4_2_prob_state, breeze_3_2_prob_state)

pit_model.add_edge(pit_4_3_prob_state, breeze_4_2_prob_state)
pit_model.add_edge(pit_4_3_prob_state, breeze_4_3_prob_state)
pit_model.add_edge(pit_4_3_prob_state, breeze_4_4_prob_state)
pit_model.add_edge(pit_4_3_prob_state, breeze_3_3_prob_state)

pit_model.add_edge(pit_4_4_prob_state, breeze_4_3_prob_state)
pit_model.add_edge(pit_4_4_prob_state, breeze_4_4_prob_state)
pit_model.add_edge(pit_4_4_prob_state, breeze_3_4_prob_state)

# %%
pit_model.bake()

# %%
pit_model.predict([[
    #pit 12, 13, 14 
    'False', 'False', 'False',
    #pit 21, 22, 23, 24 
    None, None, None, None,
    #pit 31, 32, 33, 34 
    None, None, None, None,
    #pit 41, 42, 43, 44 
    None, None, None, None,
    #breeze 11, 12, 13, 14 
    'True', None, None, None,
    #breeze 21, 22, 23, 24 
    None, None, None, None,
    #breeze 31, 32, 33, 34 
    None, None, None, None,
    #breeze 41, 42, 43, 44 
    None, None, None, None
    ]])
# Out:
#   Input In [45]
#     pit_model.predict([[[]
#                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
pit_model.probability([['True', 'False', 'False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False']])
# Out:
# 0.0

# %%
pit_model.predict([[None, 'False', 'False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False',
    'False','False','False','False']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\deqiang.wang\Documents\Github_repo\SCS3547\test_pit_prob.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/deqiang.wang/Documents/Github_repo/SCS3547/test_pit_prob.ipynb#ch0000030?line=0'>1</a> pit_model.predict([[None, 'False', 'False',
#       <a href='vscode-notebook-cell:/c%3A/Users/deqiang.wang/Documents/Github_repo/SCS3547/test_pit_prob.ipynb#ch0000030?line=1'>2</a>     'False','False','False','False',
#       <a href='vscode-notebook-cell:/c%3A/Users/deqiang.wang/Documents/Github_repo/SCS3547/test_pit_prob.ipynb#ch0000030?line=2'>3</a>     'False','False','False','False',
#       <a href='vscode-notebook-cell:/c%3A/Users/deqiang.wang/Documents/Github_repo/SCS3547/test_pit_prob.ipynb#ch0000030?line=3'>4</a>     'False','False','False','False',
# ...

# %%
pit_model.states
# Out:
# [{
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "True" : 0.2,
#                  "False" : 0.8
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "pit_1_2_prob",
#      "weight" : 1.0
#  },
#  {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "True" : 0.2,
#                  "False" : 0.8
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "pit_1_3_prob",
#      "weight" : 1.0
#  },
#  {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
# ...

# %%
stench_memory = numpy.ndarray(shape=(4,4))
for i in range(4):
    for j in range(4):
        stench_memory[i][j] = numpy.nan

stench_memory[0][0] = 1

# %%
stench_checkout = [None]
for i in range(4):
    for j in range(4):
        if stench_memory[i][j] == 1:
            stench_checkout.append('True')
        elif stench_memory[i][j] == 0:
            stench_checkout.append('False')
        else:
            stench_checkout.append(None)

# %%
print(stench_checkout)
# Out:
# [None, 'True', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
wum_loc = wumpus_model.predict_proba([stench_checkout])

# %%
type(wum_loc[0][0])
# Out:
# pomegranate.distributions.DiscreteDistribution.DiscreteDistribution

# %%
type(wum_loc[0][0].probability('2_1'))
# Out:
# float

# %%
dict = wum_loc[0][0].to_dict()
dict['parameters'][0]['2_1']
# Out:
# 0.49999999999999867
